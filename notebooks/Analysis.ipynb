# %% [markdown]
# # Shark Attack - Project 1 - Pandas  - Analysis

# %%
import scr.cleaning as cl
import scr.visualization as vis

# %%
df = cl.data_clean('C:/Users/maria/Desktop/Project_1_Pandas_Mariano/Data/attacks.csv')

# %%
df = cl.col_creation(df)

# %%
sub_df2 = cl.sub_df2_create(df)
sub_df2
# Out:
# C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Year_Unique       Date2          Day Month Hour Time_Range      Country  \
# 0            2018  2018.06.25           25   Jun   18  Afternoon          Usa
# 40           2018  2018.02.23           23   Feb   19  Afternoon    Australia
# 29           2018  2018.04.15           15   Apr   08    Morning    Australia
# 30           2018  2018.04.14           14   Apr   09    Morning      Bahamas
# 31           2018  2018.04.10  Reported 10   Apr  NaN  Afternoon       Brazil
# ...           ...         ...          ...   ...  ...        ...          ...
# ...

# %%
top_5_df = cl.top_5_df(sub_df2)
top_5_df
# Out:
#       Year_Unique       Date2          Day Month Hour Time_Range    Country  \
# 0            2018  2018.06.25           25   Jun   18  Afternoon        Usa
# 40           2018  2018.02.23           23   Feb   19  Afternoon  Australia
# 29           2018  2018.04.15           15   Apr   08    Morning  Australia
# 30           2018  2018.04.14           14   Apr   09    Morning    Bahamas
# 31           2018  2018.04.10  Reported 10   Apr  NaN  Afternoon     Brazil
# ...           ...         ...          ...   ...  ...        ...        ...
# 1919         2001  2001.08.19           19   Aug   13    Morning        Usa
# 1918         2001  2001.08.19           19   Aug   13    Morning        Usa
# 1917         2001  2001.08.21           21   Aug   16  Afternoon        Usa
# 1916         2001  2001.08.22           22   Aug   16  Afternoon        Usa
# 1915         2001  2001.08.25           25   Aug   14  Afternoon        Usa
#
#                    Area        Type  \
# ...

# %%
df.shape
# Out:
# (6302, 36)

# %%
sub_df2.shape
# Out:
# (1978, 18)

# %%
top_5_df.shape
# Out:
# (1581, 18)

# %%
cl.data_save(df,sub_df2, top_5_df)
# Out:
# 'Files saved in folder'

# %%
vis.attacks_yoy(sub_df2)

# %%
vis.risk_time_yoy(sub_df2)
